# %% [markdown]
# #### В этом ноутбуке буду собирать примеры как использую какие-то функции

# %%
import pandas as pd
import xml.etree.ElementTree as ET
from io import StringIO
import json

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Мне удобней работать с json чем xml (легче писать парсер и для vscode есть расширения, с которыми удобней руками лазать по файлам), поэтому сначала перевожу файл в json

# %%
from src.converter import *
from src.parser_fucn import *
from src.parser_main import *
from src.parser_lab import *

# %%
path_xml = '../data/test_1.xml'
path_json = '../data/test_1.json'

# %%
xml_to_json(path_xml, path_json)
with open(path_json, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %% [markdown]
# А вот так я конвертирую все файлы

# %%
paths = [('/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew1', 
          '/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew1_json'),
        ('/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew2', 
          '/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew2_json'),
        ('/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew3', 
          '/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew3_json'),]

for in_path, out_path in paths:
    process_files_in_directory(in_path, out_path)

# %% [markdown]
# Теперь в `data` у нас сохранене весь json, пока мне не
# попадаличь сильно большие файлы (сейчас все до 10к строк)
# Если когда-нибудь начнутся проблемы, нужно будет доставать оттуда только нужные куски

# %% [markdown]
# Теперь можем доставать различные куски из файлов

# %%
get_sex(data)
# Out:
# 'Мужской'

# %%
get_age(data)
# Out:
# '19601212'

# %% [markdown]
# Теперь давайте данные про госпитализацию

# %%
table, type_gosp, way_gosp = get_gosp_info(data)

# %%
table
# Out:
#          Вид нозологической единицы  \
# 0              Основное заболевание
# 1              Основное заболевание
# 2  Осложнение основного заболевания
# 3         Сопутствующее заболевание
# 4         Сопутствующее заболевание
# 5         Сопутствующее заболевание
# 6         Сопутствующее заболевание
# 7               Фоновое заболевание
#
#            Врачебное описание нозологической единицы Код по МКБ-10
# 0                ИБС. Впервые возникшая стенокардия.         I20.0
# 1                ИБС. Впервые возникшая стенокардия.         I20.0
# 2                                   ОСН 1 по Killip.         I50.1
# 3  Дегенеративный порок. Аортальный стеноз 2 степ...         I35.2
# 4  Перенесенное ОНМК по ишемическому типу в ВБС в...         I69.4
# 5  Сахарный диабет 2 типа. Целевой уровень гликог...         E11.8
# 6                Ожирение 1 степени. (ИМТ 34 кг/м2).         E66.9
# 7  Гипертоническая болезнь III стадии. Контролиру...         I11.9

# %%
type_gosp
# Out:
# 'Первичный'

# %%
way_gosp
# Out:
# 'Доставлен бригадой скорой помощи'

# %% [markdown]
# Теперь диагнозы и анамнезы

# %%
get_diagnosis(data)
# Out:
#          Вид нозологической единицы  \
# 0              Основное заболевание
# 1              Основное заболевание
# 2  Осложнение основного заболевания
# 3         Сопутствующее заболевание
# 4         Сопутствующее заболевание
# 5         Сопутствующее заболевание
# 6         Сопутствующее заболевание
# 7               Фоновое заболевание
#
#            Врачебное описание нозологической единицы Код по МКБ-10
# 0                ИБС. Впервые возникшая стенокардия.         I20.0
# 1                ИБС. Впервые возникшая стенокардия.         I20.0
# 2                                   ОСН 1 по Killip.         I50.1
# 3  Дегенеративный порок. Аортальный стеноз 2 степ...         I35.2
# 4  Перенесенное ОНМК по ишемическому типу в ВБС в...         I69.4
# 5  Сахарный диабет 2 типа. Целевой уровень гликог...         E11.8
# 6                Ожирение 1 степени. (ИМТ 34 кг/м2).         E66.9
# 7  Гипертоническая болезнь III стадии. Контролиру...         I11.9

# %% [markdown]
# Кстати тут совпало с тем что было в госпитализаци (хотя достаю из разных мест файлов)

# %%
get_amnez_d(data)
# Out:
# 'Больным себя считает с 20.00 30.12.22г, когда в покое и при минимальной ФН начал отмечать давящие боли за грудиной, длительностью до 15-20 минут, с иррадиацией в обе руки. Принял 1 дозу НТГ, с положительным эффектом. В связи с рецидивированием болей, вызвал бСМП, доставлен в ПО ОКД. \nПринимает конкор, физиотенз, фелодип, аторвастатин, варфарин, юперио, аторвастатин, форсигу.  \nПовышение АД много лет. Максимальное АД 240/мм.рт.ст. Медикаментозно достигнутое АД 130-140/мм.рт.ст. (регулярно принимает гипотензивные препараты)\nСахарный диабет 2 типа (постоянно принимает галвус, метформин )\nПеренесенное ОНМК по ишемическому типу в ВБС в 2015г.\nОИМ, БА, ЯБ ЖКТ отрицает.\nПроведен тромболизис догоспитально нет \nЭпидемиологический анамнез:\nСо слов пациента, с больными корью не контактировал(а)., В течение последнего месяца за территорию РФ не выезжал (а). Со слов пациента, с больным &quot;оспой обезьян&quot; не контактировал (а). \nБолел ранее COVID-19  да   2021г \nВакцинация от COVID-19   2021г \nРевакцинация от COVID-19 да   2022г \nПедикулез, чесотка не выявлены.\nПеренесенные заболевания: ГБ;, СД;, ОНМК; б-нь Боткина. Дегенеративный порок : Аортальный стеноз 2 степени. ( АК градиент 47мм.рт.ст) без обструкции выходного тракта; ХСН.\nТравмы: отрицает, операции: флебэктомия справа в 2010г \nАллергоанамнез: не отягощён \nГемотрансфузионный анамнез: переливание крови нет \nТуберкулез, вен. заболевания, вирусный гепатит отрицает.\nД-учет: да Поликлиника: ГП№4 Последнее посещение терапевта: 2022г'

# %%
get_amnez_life(data)
# Out:
# 'Б'

# %%
get_condition(data)
# Out:
# ['Состояние: Средней тяжести',
#  'Жалобы: на давящие боли за грудиной в покое и при минимальной ФН, длительностью до 15-20 минут, с иррадиацией в обе руки. На момент осмотра боли отрицает.',
#  'Объективный статус: \nСтепень тяжести Средней тяжести Сознание: ясное \nТелосложение гиперстеник Питание: избыточное \n РОСТ  175  ВЕС  105  ИМТ 34\nКожные покровы: физиологической окраски нормальной влажности \nТ-ра тела 36,5С, зев чистый, не гиперемирован.\nЛимфоузлы: не увеличены \nОпорно-двигательный аппарат: без патологии; Нижние конечности: физиологической окраски  не гиперемированы на ощупь теплые пульсация отчетливая при пальпации безболезненны \nДыхание: везикулярное Хрипы: не выслушиваются ЧДД 17 в мин spO2 -98%\nПеркуссия легких: при сравнительной перкуссии легкий над всей поверхностью легочных полей определяется ясный легочный звук.\nОбласть сердца и крупных сосудов не изменена \nДругие пульсации в области сердца: нет.\nВерхушеч
# 2  31.12.2022 22:00  М В Н (Заведующий (начальник) структурного под...
# 3  10.01.2023 10:00                             С А А (Врач-кардиолог)
#
#   Лечащий врач
# 0         None
# 1         None
# 2         None
# 3         None

# %% [markdown]
# По умолчанию все таблицы возвращаб как pandas dataframe, но можно и просто текстом (на самом деле dict)

# %%
get_ward_table(data, 'raw')
# Out:
# {'{urn:hl7-org:v3}table': {'{urn:hl7-org:v3}thead': {'{urn:hl7-org:v3}tr': {'{urn:hl7-org:v3}th': [{'text': 'Название'},
#      {'text': 'Дата поступления'},
#      {'text': 'Дата перевода'},
#      {'text': 'Профиль койки'},
#      {'text': 'Лечащий врач'}]}},
#   '{urn:hl7-org:v3}tbody': {'{urn:hl7-org:v3}tr': [{'{urn:hl7-org:v3}td': [{'{urn:hl7-org:v3}content': {'text': 'Приемное отделение'}},
#       {'{urn:hl7-org:v3}content': {'text': '30.12.2022 07:32'}},
#       {'{urn:hl7-org:v3}content': {'text': '30.12.2022 07:41'}},
#       {'{urn:hl7-org:v3}content': {'text': 'С А А (Врач-кардиолог)'}}]},
#     {'{urn:hl7-org:v3}td': [{'{urn:hl7-org:v3}content': {'text': 'Кардиологическое отделение с ПРиИТ для лечения больных с ОКС (ПСО) №1'}},
#       {'{urn:hl7-org:v3}content': {'text': '30.12.2022 07:42'}},
#       {'{urn:hl7-org:v3}content': {'text': '30.12.2022 11:59'}},
#       {'{urn:hl7-org:v3}content': {'text': 'С А А (Врач-кардиолог)'}}]},
#     {'{urn:hl7-org:v3}td': [{'{urn:hl7-org:v3}content': {'text': 'Отделение анестезиологии-реанимации с палатами реанимации и интенсивной терапии №2'}},
#       {'{urn:hl7-org:v3}content': {'text': '30.12.2022 12:00'}},
#       {'{urn:hl7-org:v3}content': {'text': '31.12.2022 22:00'}},
#       {'{urn:hl7-org:v3}content': {'text': 'М В Н (Заведующий (начальник) структурного подразделения (отдела, отделения, лаборатории, кабинета, отряда и другое) медицинской организации - врач-специалист, специалист)'}}]},
#     {'{urn:hl7-org:v3}td': [{'{urn:hl7-org:v3}content': {'text': 'Кардиологическое отделение с ПРиИТ для лечения больных с ОКС (ПСО) №1'}},
#       {'{urn:hl7-org:v3}content': {'text': '31.12.2022 22:01'}},
#       {'{urn:hl7-org:v3}content': {'text': '10.01.2023 10:00'}},
#       {'{urn:hl7-org:v3}content': {'text': 'С А А (Врач-кардиолог)'}}]}]},
#   'width': '100%'}}

# %%
type(get_ward_table(data, 'raw'))
# Out:
# dict

# %% [markdown]
# Дальше надо доставать исследования по каждому из отделений(пока только в сыром виде)

# %%
get_ward_list(data)

# %%
get_final(data)

# %% [markdown]
# Извлекаю признаки из json и сохраняю в json, но теперь более понятного порядка

# %%
paths = [('/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew1_json', 
         '/Users/maximzabelin/My/edc/hse4/data/med_records/d1_features'), 
        ('/Users/maximzabelin/My/edc/hse4/data/med_records/DocsNew2_json', 
         '/Users/maximzabelin/My/edc/hse4/data/med_records/d2_features')]

for in_path, out_path in paths:
    save_features(in_path, out_path)

# %% [markdown]
# Также вот немного по лабораторынм файлам

# %%
path_xml_lab = '../data/test_lab_1.xml'
path_json_lab = '../data/test_lab_1.json'

xml_to_json(path_xml_lab, path_json_lab)

with open(path_json_lab, 'r', encoding='utf-8') as file:
    data_lab = json.load(file)

# %%
get_table_1(data_lab)
# Out:
#                                            Показатель  \
# 0                               КОР артерильной крови
# 1   Водородный показатель (pH) артериальной крови,...
# 2   Кислород общий, молярная концентрация в венозн...
# 3       Водородный показатель (pH) артериальной крови
# 4   Диоксид углерода, парциальное давление в артер...
# 5   Кислород, парциальное давление в артериальной ...
# 6   Насыщение гемоглобина кислородом, массовая фра...
# 7     Гемоглобин общий, массовая концентрация в крови
# 8   Гематокрит крови методом автоматизированного п...
# 9   Оксигемоглобин, массовая фракция в артериально...
# 10  Карбоксигемоглобин, массовая фракция в артериа...
# 11  Метгемоглобин, массовая фракция в артериальной...
# 12  Бикарбонат стандартный, молярная концентрация ...
# 13  Избыток оснований стандартный, расчетная моляр...
# 14  Избыток оснований актуальный, расчетная молярн...
# 15  Калий, молярная концентрация в артериальной крови
# 16  Натрий, молярная концентрация в артериальной к...
# 17  Кальций ионизированный, молярная концентрация ...
# 18  Хлориды, молярная концентрация в артериальной ...
# 19  Глюкоза, молярная концентрация в артериальной ...
# 20  Лактат, молярная концентрация в артериальной к...
# 21  Кислород общий, молярная концентрация в артери...
# 22  Кислород, парциальное давление при 50% сатурац...
# 23  Отношение альвеолярно-артериального градиента ...
# 24  Билирубин общий, молярная концентрация в веноз...
#
#    Значение / чувствительность (для бак.исследований) Единицы измерения  \
# 0                                                None              None
# 1                                                  36      безразм. ед.
# 2                                                  40                 %
# 3                                               7.297                pH
# 4                                                44.7         мм.рт.ст.
# 5                                                73.5         мм.рт.ст.
# 6                                                93.3                 %
# 7                                                 122               г/л
# 8                                                37.7                 %
# 9                                                91.4                 %
# 10                                                0.8                 %
# 11                                                1.2                 %
# 12                                               21.2           ммоль/л
# 13                                               -4.2           ммоль/л
# 14                                               -4.7           ммоль/л
# 15                                                3.8           ммоль/л
# 16                                                137           ммоль/л
# 17                                               0.94           ммоль/л
# 18                                                107           ммоль/л
# 19                                               10.2           ммоль/л
# 20                                                1.1           ммоль/л
# 21                                               15.8           ммоль/л
# 22                                              29.11         мм.рт.ст.
# 23                                               22.8                 %
# 24                                                 18          мкмоль/л
#
#    Референтный диапазон                                  Комментарий  \
# 0                  None                                         None
# 1                     -                                         None
# 2                     -                                         None
# 3        7.35 - 7.45 pH  Патологический (вне референсного диапазона)
# 4     35 - 48 мм.рт.ст.                                         None
# 5    83 - 108 мм.рт.ст.  Патологический (вне референсного диапазона)
# 6             95 - 99 %  Патологический (вне референсного диапазона)
# 7         135 - 165 г/л  Патологический (вне референсного диапазона)
# 8             39 - 50 %  Патологический (вне референсного диапазона)
# 9             94 - 99 %  Патологический (вне референсного диапазона)
# 10            0 - 0.8 %  Патологический (вне референсного диапазона)
# 11            0 - 0.5 %  Патологический (вне референсного диапазона)
# 12      24 - 31 ммоль/л  Патологический (вне референсного диапазона)
xml_to_json(path_xml_lab, path_json_lab)

with open(path_json_lab, 'r', encoding='utf-8') as file:
    data_lab = json.load(file)

# %%
get_table_1(data_lab)
# Out:
#                                            Показатель  \
# 0                                  КОР венозной крови
# 1   Водородный показатель (pH) венозной крови, отк...
# 2   Кислород общий, молярная концентрация в венозн...
# 3           Водородный показатель (pH) венозной крови
# 4   Диоксид углерода, парциальное давление в веноз...
# 5   Кислород общий, молярная концентрация в венозн...
# 6   Насыщение гемоглобина кислородом, массовая фра...
# 7     Гемоглобин общий, массовая концентрация в крови
# 8   Гематокрит крови методом автоматизированного п...
# 9   Оксигемоглобин, массовая фракция в венозной крови
# 10  Карбоксигемоглобин, массовая фракция в венозно...
# 11   Метгемоглобин, массовая фракция в венозной крови
# 12  Бикарбонат стандартный, молярная концентрация ...
# 13  Избыток оснований стандартный, расчетная моляр...
# 14  Избыток оснований истинный, расчетная молярная...
# 15      Калий, молярная концентрация в венозной крови
# 16     Натрий, молярная концентрация в венозной крови
# 17  Кальций ионизированный, молярная концентрация ...
# 18    Хлориды, молярная концентрация в венозной крови
# 19    Глюкоза, молярная концентрация в венозной крови
# 20     Лактат, молярная концентрация в венозной крови
# 21  Кислород общий, молярная концентрация в венозн...
# 22  Кислород, парциальное давление при 50% сатурац...
# 23  Билирубин общий, молярная концентрация в веноз...
#
#    Значение / чувствительность (для бак.исследований) Единицы измерения  \
# 0                                                None              None
# 1                                                36.6      безразм. ед.
# 2                                                  21                 %
# 3                                               7.359                pH
# 4                                                42.6         мм.рт.ст.
# 5                                                38.7           ммоль/л
# 6                                                69.4                 %
# 7                                                 179               г/л
# 8                                                54.7                 %
# 9                                                67.1                 %
# 10                                                2.2                 %
# 11                                                1.1                 %
# 12                                               23.4           ммоль/л
# 13                                               -1.3           ммоль/л
# 14                                               -1.7           ммоль/л
# 15                                                3.9           ммоль/л
# 16                                                138           ммоль/л
# 17                                               1.04           ммоль/л
# 18                                                111           ммоль/л
# 19                                                6.1           ммоль/л
# 20                                                  2           ммоль/л
# 21                                               16.8           ммоль/л
# 22                                              28.59         мм.рт.ст.
# 23                                                 25          мкмоль/л
#
#    Референтный диапазон                                  Комментарий  \
# 0                  None                                         None
# 1                     -                                         None
# 2                     -                                         None
# 3        7.32 - 7.42 pH                                         None
# 4     42 - 55 мм.рт.ст.                                         None
# 5       37 - 42 ммоль/л                                         None
# 6             60 - 80 %                                         None
# 7         135 - 165 г/л  Патологический (вне референсного диапазона)
# 8             39 - 50 %  Патологический (вне референсного диапазона)
# 9             60 - 80 %                                         None
# 10            18 - 38 %  Патологический (вне референсного диапазона)
# 11          0.2 - 0.4 %  Патологический (вне референсного диапазона)
# 12      24 - 31 ммоль/л  Патологический (вне референсного диапазона)
# 13       -3 - 3 ммоль/л                                         None
# 14       -3 - 3 ммоль/л                                         None
# 15      3.5 - 5 ммоль/л                                         None
# 16    135 - 145 ммоль/л                                         None
# 17  1.15 - 1.29 ммоль/л  Патологический (вне референсного диапазона)
# 18     98 - 106 ммоль/л  Патологический (вне референсного диапазона)
# 19    3.5 - 6.1 ммоль/л                                         None
# 20      0.5 - 3 ммоль/л                                         None
# 21                    -                                         None
# 22                    -                                         None
# 23      5 - 21 мкмоль/л  Патологический (вне референсного диапазона)
#
#          Оборудование              Дата               Исполнитель
# 0                None              None                      None
# 1   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 2   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 3   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 4   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 5   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 6   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 7   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 8   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 9   ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 10  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 11  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 12  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 13  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 14  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 15  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 16  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 17  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 18  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 19  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 20  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 21  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 22  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.
# 23  ABL800_4-228-Left  13.07.2023 23:27  Фельдшер-лаборант У Т.А.

# %%
path_xml_lab = '../data/file3_1 copy.xml'
path_json_lab = '../data/file3_1 copy.json'

xml_to_json(path_xml_lab, path_json_lab)

with open(path_json_lab, 'r', encoding='utf-8') as file:
    data_lab = json.load(file)

# %%
get_table_1(data_lab)
# Out:
#                                           Показатель  \
# 0    Исследование уровня глюкозы в капиллярной крови
# 1  Глюкоза, молярная концентрация в капиллярной к...
#
#   Значение / чувствительность (для бак.исследований) Единицы измерения  \
# 0                                               None              None
# 1                                                5.5           ммоль/л
#
#   Референтный диапазон Комментарий Оборудование              Дата  \
# 0                 None        None         None              None
# 1    3.9 - 5.8 ммоль/л        None         None  19.08.2023 06:45
#
#                 Исполнитель
# 0                      None
# 1  Фельдшер-лаборант К Э.Ш.
